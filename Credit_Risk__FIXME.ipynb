# %% [markdown]
# #Import Libraries

# %%
# Data handling
import pandas as pd
import numpy as np
from sklearn.model_selection import "FIXME"
from sklearn.preprocessing import StandardScaler
from sklearn.linear_model import "FIXME"
from sklearn.metrics import accuracy_score, confusion_matrix, classification_report
import matplotlib.pyplot as "FIXME"
import seaborn as "FIXME"

# %% [markdown]
# # Load Dataset

# %%
import pandas as pd

# Organizer trial – use Group A
df = pd."FIXME"("credit_risk_data.csv")
df."FIXME"()
# Out:
#    income  credit_score  existing_emis  past_default  risk
# 0  103810           607              0             1     1
# 1   52098           664              1             1     1
# 2  108696           829              0             0     0
# 3   24165           565              0             0     1
# 4   86237           563              4             0     1

# %% [markdown]
# # Preprocessing

# %%
# Check for missing values in each column
df.isnull()."FIXME"()
# Check structure and missing values
df.info()
# Statistical summary
df."FIXME"()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2000 entries, 0 to 1999
# Data columns (total 5 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   income         2000 non-null   int64
#  1   credit_score   2000 non-null   int64
#  2   existing_emis  2000 non-null   int64
#  3   past_default   2000 non-null   int64
#  4   risk           2000 non-null   int64
# dtypes: int64(5)
# memory usage: 78.3 KB
#              income  credit_score  existing_emis  past_default         risk
# count    2000.00000   2000.000000    2000.000000   2000.000000  2000.000000
# mean    70922.85650    704.436500       2.033000      0.285500     0.710500
# std     28852.90895     86.890949       1.433855      0.451765     0.453644
# min     20089.00000    550.000000       0.000000      0.000000     0.000000
# 25%     45027.25000    626.000000       1.000000      0.000000     0.000000
# ...

# %% [markdown]
# # Feature & Target Separation

# %%
# Features (input variables)
X = df.drop("risk", axis=1)
# Target variable
y = df["FIXME"]

# %% [markdown]
# # Train–Test Split

# %%
# Split dataset into training and testing data
X_train, X_test, y_train, y_test = "FIXME"(
    X, y, test_size=0.25, random_state=42
)

# %% [markdown]
# # Feature Scaling

# %%
# Initialize scaler
scaler ="FIXME"r()
# Scale training data
X_train_scaled = scaler.fit_transform("FIXME")
# Scale testing data
X_test_scaled = scaler.transform("FIXME")

# %% [markdown]
# # Model Training

# %%
# Initialize Logistic Regression model
model = "FIXME"()
# Train the model
model.fit(X_train_scaled, "FIXME")
# Out:
# LogisticRegression()

# %% [markdown]
# # Prediction

# %%
# Predict on test data
y_pred = model."FIXME"(X_test_scaled)

# %% [markdown]
# # Model Evaluation

# %%
# Accuracy score
print("Accuracy:", accuracy_score(y_test, "FIXME"))
# Detailed classification metrics
print("\nClassification Report:\n")
print("FIXME"("FIXME", y_pred))
# Out:
# Accuracy: 0.908
#
# Classification Report:
#
#               precision    recall  f1-score   support
#
#            0       0.82      0.84      0.83       134
#            1       0.94      0.93      0.94       366
#
#     accuracy                           0.91       500
#    macro avg       0.88      0.89      0.88       500
# weighted avg       0.91      0.91      0.91       500

# %% [markdown]
# # Confusion Matrix Visualization

# %%
# Generate confusion matrix
cm = confusion_matrix(y_test, y_pred)
# Plot confusion matrix
sns.heatmap(cm, annot=True, fmt="d", cmap="Blues")
plt.xlabel("Predicted")
plt.ylabel("Actual")
plt.title("Credit Risk Confusion Matrix")
plt.show()

# %% [markdown]
# # Predict for New Applicant

# %%
# New applicant data: income, credit score, EMIs, defaults
new_applicant = [[45000, 700, 2, 0]]
# Scale new applicant data
new_scaled = scaler.transform(new_applicant)
# Predict risk category
prediction = model.predict(new_scaled)
# Output result
if prediction[0] == 1:
    print("⚠️ High Credit Risk")
else:
    print("✅ Low Credit Risk")
# Out:
# ⚠️ High Credit Risk
# /usr/local/lib/python3.12/dist-packages/sklearn/utils/validation.py:2739: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
